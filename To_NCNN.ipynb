# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())
torch.cuda.set_device(0)
# Out:
# True
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
model = YOLO('qr1.pt')

# %%
model.export(format="ncnn")
# Out:
# Ultralytics YOLOv8.2.68  Python-3.12.4 torch-2.4.0 CPU (13th Gen Intel Core(TM) i7-13700H)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'qr1.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
#
# TorchScript: starting export with torch 2.4.0...
# TorchScript: export success  1.2s, saved as 'qr1.torchscript' (11.9 MB)
#
# NCNN: starting export with NCNN 1.0.20240410...
# NCNN: running 'D:\Users\JoJo\anaconda3\Lib\site-packages\ultralytics\pnnx.exe qr1.torchscript ncnnparam=qr1_ncnn_model\model.ncnn.param ncnnbin=qr1_ncnn_model\model.ncnn.bin ncnnpy=qr1_ncnn_model\model_ncnn.py pnnxparam=qr1_ncnn_model\model.pnnx.param pnnxbin=qr1_ncnn_model\model.pnnx.bin pnnxpy=qr1_ncnn_model\model_pnnx.py pnnxonnx=qr1_ncnn_model\model.pnnx.onnx fp16=0 device=cpu inputshape="[1, 3, 640, 640]"'
# NCNN: export success  1.6s, saved as 'qr1_ncnn_model' (11.6 MB)
#
# Export complete (4.6s)
# Results saved to D:\Random Codes\Qrcode
# Predict:         yolo predict task=detect model=qr1_ncnn_model imgsz=640
# Validate:        yolo val task=detect model=qr1_ncnn_model imgsz=640 data=/content/hatters-7/data.yaml
# Visualize:       https://netron.app
# 'qr1_ncnn_model'

# %%
ncnn_model=YOLO("qr1_ncnn_model")
# Out:
# WARNING  Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.

# %%
img_path = r"C:\Users\JoJo\Downloads\qrcode\photo_2024-08-18_09-15-10.jpg"

# %%
img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
results= ncnn_model(img)
# Out:
# 0: 640x640 1 0, 66.7ms
# Speed: 4.0ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
